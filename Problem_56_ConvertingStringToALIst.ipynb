# %%
# 56. Write a Python program to convert a string to a list.
color = "['Red', 'Green', 'White']"
# Out:
# ["['Red', 'Green', 'White']"]

# %%
# Import the 'ast' module, which provides a safe way to evaluate Python literals
import ast

# Define a string 'color' containing a Python list as a string
color = "['Red', 'Green', 'White']"

# Use the 'ast.literal_eval' function to safely evaluate the string as a Python literal expression
# This function ensures that the string is treated as a valid Python literal, in this case, a list
# Print the result, which is the actual list created from the string
print(ast.literal_eval(color))
# Out:
# ['Red', 'Green', 'White']

# %%
import ast
a = "('red', 'green', 'white')"
str_tuple = ast.literal_eval(a)
print(str_tuple)
print(type(str_tuple))
# Out:
# ('red', 'green', 'white')
# <class 'tuple'>

# %%
b = "{'color1': 'red', 'color2': 'blue', 'color3': 'green'}"
str_dic = ast.literal_eval(b)
print(str_dic)
print(type(str_dic))
# Out:
# {'color1': 'red', 'color2': 'blue', 'color3': 'green'}
# <class 'dict'>

# %%
c = '10'
str_int = ast.literal_eval(c)
print(str_int)
print(type(str_int))
# Out:
# 10
# <class 'int'>

# %%
d = '3.5234'
str_float = ast.literal_eval(d)
print(str_float)
print(type(str_float))
# Out:
# 3.5234
# <class 'float'>

# %%
e ='{3, 5, 5, 8, 2}'
str_set = ast.literal_eval(e)
print(str_set)
print(type(str_set))
# Out:
# {8, 2, 3, 5}
# <class 'set'>
