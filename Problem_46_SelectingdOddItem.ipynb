# %%
# 46. Write a Python program to select the odd items of a list.
k = [21, 22, 1, 2, 3, 4, 5, 23, 24, 25, 11, 12, 13, 14, 15]
g = []

for i in k[1::2]:
    g.append(i)
print(f"These are the odd items in the list: {g}")
# Out:
# These are the odd items in the list: [22, 2, 4, 23, 25, 12, 14]
