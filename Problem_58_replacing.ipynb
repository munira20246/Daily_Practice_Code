# %%
# 58. Write a Python program to replace the last element in a list with another list.

x = [1, 3, 5, 7, 9, 10]
y = [2, 4, 6, 8]

x[-1:] = y
print(x)
# Out:
# [1, 3, 5, 7, 9, 2, 4, 6, 8]

# %%
x = [1, 3, 5, 7, 9, 10]
y = [2, 4, 6, 8]

t = x.pop()
for i in y:
    x.append(i)
print(x)
