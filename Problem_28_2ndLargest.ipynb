# %%
#28. Write a Python program to find the second largest number in a list.
l = [49, 64, 2, 30, 5, 36]

a = set(l)
b = list(sorted(a))
b[-2]
# Out:
# 49

# %%
def scnlar(x):
    x = [49, 64, 2, 30, 5, 36]

    a = set(x)
    b = list(sorted(a))

    return b[-2]
l = [49, 64, 2, 30, 5, 36]
scnlar(l)
# Out:
# 49
