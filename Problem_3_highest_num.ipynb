# %%
#3. Write a Python program to get the largest number from a list.
h = [20, 5, 9, 3, 10, 8, 6, 4, 7]
highest_num = 0
for i in h:
  if i > highest_num:
    highest_num = i
print(highest_num)

# %%
h = [2, 5, 9, 3, 1, 8, 6, 4, 7]

highest_n = max(h)
print(highest_n)

# %%
def maximum_number(m):
  n = 0
  for i in m:
    if i > n:
      n = i
  print(f"\nThe maximum number from the list {m} is {n}")
li = []
maximum_number(li)
