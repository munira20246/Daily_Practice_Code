# %%
zx = [49, 64, 2, 1, 30, 5, 36]

xz = set(zx)
x = list(sorted(xz))
x[1]
# Out:
# 2

# %%
def ScnSm(x):
    y = set(x)
    z = list(sorted(y))
    x = z[1]
    return x
xz = [49, 64, 2, 1, 30, 5, 36]
ScnSm(xz)
# Out:
# 2

# %%
'''27. Write a Python program to find the second smallest number in a list.'''
xz = [49, 64, 2, 30, 5, 36]
smallest = float('inf')
second_smallest = float('inf')

for i in xz:
  if i < smallest:
    second_smallest = smallest
    smallest = i
  elif smallest < i < second_smallest:
    second_smallest = i

if second_smallest != float('inf'):
    print(f"The second smallest number in the list {xz} is: {second_smallest}")
# Out:
# The second smallest number in the list [49, 64, 2, 30, 5, 36] is: 5

# %%
def secondSmallest(a):
  smallest = float('inf')
  second_smallest = float('inf')

  for i in a:
    if i < smallest:
       second_smallest = smallest
       smallest = i
    elif smallest < i < second_smallest:
       second_smallest = i

  if second_smallest != float('inf'):
       print(f"The second smallest number in the list {a} is: {second_smallest}")

       
xz = [49, 64, 2, 30, 5, 36]
secondSmallest(xz)
# Out:
# The second smallest number in the list [49, 64, 2, 30, 5, 36] is: 5
