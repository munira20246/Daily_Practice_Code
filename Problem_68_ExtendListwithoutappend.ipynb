# %%
# 68. Write a Python program to extend a list without append.

ls = [10, 20, 30]
y = [40, 50, 60]
z = y + ls
print(z)
# Out:
# [40, 50, 60, 10, 20, 30]

# %%
ls = [10, 20, 30]
y = [40, 50, 60]
y.extend(ls)
print(y)
# Out:
# [40, 50, 60, 10, 20, 30]

# %%
x = [10, 20, 30]
y = [40, 50, 60]

x[:0] = y
print(x)
# Out:
# [40, 50, 60, 10, 20, 30]
