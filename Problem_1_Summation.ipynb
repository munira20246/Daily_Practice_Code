# %%
#1. Write a Python program to sum all the items in a list.
# summation of the item using sum() function.
d = [2, 5, 9, 3, 1, 8, 6, 4, 7]

d = sum(d)
d

# %%
# Summation of the item using for loop.
h = [2, 5, 9, 3, 1, 8, 6, 4, 7]
coount = 0
for i in h:
  coount += i
print(coount)
# Out:
# 45

# %%
#Summation of the item using user defined function.

def add(x):
  coount = 0
  for i in x:
    coount += i
  print(f"The Summation of the numbers {x} is---{coount}")

c = [2, 5]
add(c)

def list_maker(a):
  n = int(input("Enter a number---"))
  for i in range(n):
       y = int(input("Enter numbers for making a list---"))
       a.append(y)
  return a

c = []
list_maker(c)

add(c)
