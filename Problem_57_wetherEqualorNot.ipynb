# %%
# 57. Write a Python program to check whether all items of a list is equal to a given
# string.

color1 = ["green", "orange", "black", "white"]


print(all(c == 'green' for c in color1))
# Out:
# False

# %%
color2 = ["green", "green", "green", "green"]
print(all(c == 'green' for c in color2))
# Out:
# True

# %%
color1 = ["green", "green", "green", "green", "green"]
# color2 = ["green", "green", "black", "orange"]
c = 0
for i in color1:
    if i == color1[0]:
        c += 1
b = c == len(color1)            
print(b)
# Out:
# True
