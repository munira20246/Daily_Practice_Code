# %%
# 71. Write a Python program to check whether all 
# dictionaries in a list are empty or not.
ldic = [{},{},{}]
dicf = [{},{12: 'o'},{2: 'y'}]
b = all(not d for d in ldic)
c = all(not d for d in dicf)
print(b)
print(c)
# Out:
# True
# False
