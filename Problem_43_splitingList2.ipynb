# %%
# 43. Write a Python program to split a list into different variables.
color = [("Black", "(0, 0, 0)"), ("Red", "(255, 0, 0)"), ("Yellow", "(255, 255, 0)"), ("Green", "(255, 0, 255)")]

v1, v2, v3, v4 = color
print(v1)
print(v2)
print(v3)
print(v4)
# Out:
# ('Black', '(0, 0, 0)')
# ('Red', '(255, 0, 0)')
# ('Yellow', '(255, 255, 0)')
# ('Green', '(255, 0, 255)')
